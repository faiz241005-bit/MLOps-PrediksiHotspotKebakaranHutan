# %% [markdown]
# # FireGuard — Initial EDA (Stub)
#
# **Branch:** `feat/initial-eda`
# **Tujuan:** explorasi awal struktur data NASA FIRMS dan cuaca untuk memvalidasi feasibility model.
#
# Notebook ini akan diisi pada LK03. Saat ini hanya placeholder agar struktur direktori sudah siap.
#
# ## Rencana Isi (LK03)
#
# 1. Setup environment & verifikasi koneksi API
# 2. Fetch sampel NASA FIRMS untuk Riau (1 minggu, musim kemarau 2024)
# 3. Distribusi `frp` (Fire Radiative Power), `confidence`
# 4. Time-series harian hotspot per provinsi
# 5. Korelasi cuaca ↔ hotspot (lag 24/72 jam)
# 6. Identifikasi data quality issues (missing, duplikat, outlier)
#
# ## Catatan Keamanan
#
# API key diambil dari `.env` via `python-dotenv`, **tidak hard-coded** di notebook.
# Output cell **wajib di-strip** sebelum commit (pre-commit `nbstripout` aktif).

# %%
# Placeholder — akan diisi LK03
import os
from dotenv import load_dotenv

load_dotenv()
FIRMS_KEY = os.getenv("NASA_FIRMS_API_KEY")
assert FIRMS_KEY, "NASA_FIRMS_API_KEY belum di-set di .env"
print("Setup OK — siap untuk EDA.")
